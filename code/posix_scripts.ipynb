# %%
# !git clone https://github.com/kowndinya-renduchintala/POSIX.git
# %cd POSIX
# !pip install -e .
# !pip install .
# !pip install transformers accelerate
# Out:
# Cloning into 'POSIX'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 31 (delta 9), reused 23 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (31/31), 675.84 KiB | 5.24 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/POSIX/POSIX
# Obtaining file:///content/POSIX/POSIX
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from prompt-sensitivity-index==0.0.1) (2.6.0+cpu)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from prompt-sensitivity-index==0.0.1) (4.51.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->prompt-sensitivity-index==0.0.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->prompt-sensitivity-index==0.0.1) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->prompt-sensitivity-index==0.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->prompt-sensitivity-index==0.0.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->prompt-sensitivity-index==0.0.1) (2025.3.2)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->prompt-sensitivity-index==0.0.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->prompt-sensitivity-index==0.0.1) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (4.67.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->prompt-sensitivity-index==0.0.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->prompt-sensitivity-index==0.0.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->prompt-sensitivity-index==0.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->prompt-sensitivity-index==0.0.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->prompt-sensitivity-index==0.0.1) (2025.1.31)
# Building wheels for collected packages: prompt-sensitivity-index
#   Building editable for prompt-sensitivity-index (pyproject.toml) ... done
#   Created wheel for prompt-sensitivity-index: filename=prompt_sensitivity_index-0.0.1-0.editable-py3-none-any.whl size=5292 sha256=dd3b1008a6acad8525ef13565ea7c774ab025d6ab463634c27a457bd7508b071
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r30_zu2d/wheels/fa/5e/95/6278f1d3c846c1af6fd590228d657b3d01af6ac3c2e0ef3a7e
# Successfully built prompt-sensitivity-index
# Installing collected packages: prompt-sensitivity-index
#   Attempting uninstall: prompt-sensitivity-index
#     Found existing installation: prompt-sensitivity-index 0.0.1
#     Uninstalling prompt-sensitivity-index-0.0.1:
#       Successfully uninstalled prompt-sensitivity-index-0.0.1
# Successfully installed prompt-sensitivity-index-0.0.1
# Processing /content/POSIX/POSIX
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from prompt-sensitivity-index==0.0.1) (2.6.0+cpu)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from prompt-sensitivity-index==0.0.1) (4.51.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->prompt-sensitivity-index==0.0.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->prompt-sensitivity-index==0.0.1) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->prompt-sensitivity-index==0.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->prompt-sensitivity-index==0.0.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->prompt-sensitivity-index==0.0.1) (2025.3.2)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->prompt-sensitivity-index==0.0.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->prompt-sensitivity-index==0.0.1) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers->prompt-sensitivity-index==0.0.1) (4.67.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->prompt-sensitivity-index==0.0.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->prompt-sensitivity-index==0.0.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->prompt-sensitivity-index==0.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->prompt-sensitivity-index==0.0.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->prompt-sensitivity-index==0.0.1) (2025.1.31)
# Building wheels for collected packages: prompt-sensitivity-index
#   Building wheel for prompt-sensitivity-index (pyproject.toml) ... done
#   Created wheel for prompt-sensitivity-index: filename=prompt_sensitivity_index-0.0.1-py3-none-any.whl size=9156 sha256=53232a26c9f138858d267b46b66f1bf2a91cff2acc02ab5dabebfe06b8a4f63e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3ctzwngc/wheels/fa/5e/95/6278f1d3c846c1af6fd590228d657b3d01af6ac3c2e0ef3a7e
# Successfully built prompt-sensitivity-index
# Installing collected packages: prompt-sensitivity-index
#   Attempting uninstall: prompt-sensitivity-index
#     Found existing installation: prompt-sensitivity-index 0.0.1
#     Uninstalling prompt-sensitivity-index-0.0.1:
#       Successfully uninstalled prompt-sensitivity-index-0.0.1
# Successfully installed prompt-sensitivity-index-0.0.1
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.5.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cpu)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from prompt_sensitivity_index.models import HFModel
from prompt_sensitivity_index.posix import (
    PosixConfig,
    get_prompt_sensitivity,
    write_trace_to_json
)
import json

# %%
#example from their repo - https://github.com/kowndinya-renduchintala/POSIX

# Example intent-aligned prompt sets
intent_aligned_prompts = [
    [
        "Q: What is the capital of France?\nA: ",
        "Q: WHat is te capital city of France?\nA: ",
        "Q: what is teh cpital of france??\nA: "
    ],
    [
        "Q: What is the national animal of India?\nA: ",
        "Q: What's the national animl of India?\nA: ",
        "Q: WHat is teh national animal of India?\nA: "
    ],
    [
        "Q: Tell me the meaning of rendezvous?\nA: ",
        "Q: WHat is the meaning of rendezvous?\nA: ",
        "Q: What does rendezvous mean?\nA: "
    ]
]

model_name = "openai-community/gpt2"
model = HFModel(model_name)
config = PosixConfig(max_new_tokens=10, batched=False)
posix_score, trace = get_prompt_sensitivity(model, intent_aligned_prompts, config, verbose=True)
print(f"Prompt Sensitivity Index: {posix_score:.4f}")
write_trace_to_json(trace, "posix_trace.json")

# Show first few prompts, responses, and logprobs
for i, group in enumerate(trace.prompt_sensitivities):
    print(f"\n--- Prompt Group {i+1} ---")
    for j, prompt in enumerate(trace.prompts[i]):
        print(f"Prompt: {prompt}")
        print(f"Response: {trace.responses[i][j]}")
        print(f"Logprobs: {trace.logprob_matrices[i][j]}")
    print(f"Sensitivity: {trace.prompt_sensitivities[i]}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Setting pad token to <|endoftext|>
# Total Number of Intent-Aligned Prompt Sets: 3
#   0%|          | 0/3 [00:00<?, ?it/s]
# Prompt Sensitivity for Prompt Set 2: 0.6173056702313867
# Prompt Sensitivity for Prompt Set 2: 0.3238119387223075
# Prompt Sensitivity for Prompt Set 2: 0.24405630541344484
# Prompt Sensitivity Index (POSIX): 0.39505797145571303
# Prompt Sensitivity Index: 0.3951
#
# --- Prompt Group 1 ---
# Prompt: Q: What is the capital of France?
# A:
# Response:  The capital of France is Paris.
# Logprobs: [-7.3389575749170035, -10.418194237689022, -18.44031661748886]
# Prompt: Q: WHat is te capital city of France?
# A:
# Response:  I don't know. I don't know
# Logprobs: [-12.146543082839344, -10.77430819813162, -18.70745277404785]
# Prompt: Q: what is teh cpital of france??
# A:
# Response:  I think it's a bit of a mis
# Logprobs: [-26.656580751470756, -13.104215703555383, -18.079093247652054]
# Sensitivity: 0.6173056702313867
#
# --- Prompt Group 2 ---
# Prompt: Q: What is the national animal of India?
# A:
# Response:  India is a country of animals.
# Logprobs: [-13.596061000833288, -18.71247360110283, -15.023666113615036]
# Prompt: Q: What's the national animl of India?
# A:
# Response:  India is a country of people who are not
# Logprobs: [-19.840873851731885, -16.572465509176254, -15.908844143152237]
# Prompt: Q: WHat is teh national animal of India?
# A:
# Response:  I am not sure. I am not sure
# Logprobs: [-17.487343248154502, -21.27696019411087, -14.90581727027893]
# Sensitivity: 0.3238119387223075
#
# --- Prompt Group 3 ---
# Prompt: Q: Tell me the meaning of rendezvous?
# A:
# Response:  I think it's a good question.
# Logprobs: [-14.45431599020958, -17.584929052740335, -19.166738837957382]
# Prompt: Q: WHat is the meaning of rendezvous?
# A:
# Response:  I think it's a reference to the fact
# Logprobs: [-14.635683327913284, -17.12910995259881, -18.40879699587822]
# Prompt: Q: What does rendezvous mean?
# A:
# Response:  It means that the ship is in the middle
# Logprobs: [-15.000468403100967, -18.027697149664164, -16.634131580591202]
# Sensitivity: 0.24405630541344484

# %%
# Load uploaded JSON (use your filename!)
with open("/content/alpaca_prompts.json", "r") as f:
    raw_data = json.load(f)

# %%
print("GPT2")
# Extract paraphrased prompts (testing first 2 groups now)
intent_aligned_prompts = [entry["prompts"] for entry in raw_data[:2]]

# Load model
# EleutherAI/gpt-neo-125M, mistralai/Mistral-7B-Instruct-v0.2
model = HFModel("openai-community/gpt2")

# Config
config = PosixConfig(max_new_tokens=20, batched=True)

# Run
score, trace = get_prompt_sensitivity(model, intent_aligned_prompts, config)
print(f"\nPSI score: {score:.4f}")
# Out:
# =====
# GPT2
# Setting pad token to <|endoftext|>
#   0%|          | 0/2 [00:00<?, ?it/s]
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
# PSI score: 0.4396

# %%
print("Total prompts in trace:", len(trace.prompts))
print("Total responses in trace:", len(trace.responses))

# Check first 3 prompts and responses
for i in range(min(3, len(trace.prompts))):
    print(f"\nPrompt {i}: {trace.prompts[i]}")
    print(f"Response {i}: {trace.responses[i]}")
# Out:
# Total prompts in trace: 2
# Total responses in trace: 2
#
# Prompt 0: ['Q:How much do you know about Buddhism?\nA: ', 'Q:How much so yeou know about Buddhism ?\nA: ', 'Q:Hlow much do you know about Buddhism ?\nA: ', 'Q:How much do you know about huddhism ?\nA: ', 'Q:Hw muh dpo ypu knw abouht Buddhiism ?\nA: ', 'Q:yow much dmo oyu know about Buddhism ?\nA: ', 'Q:How much ddo you knod about Buddhism ?\nA: ', 'question: How much do you know about Buddhism?\nanswer: ', 'Question: How much do you know about Buddhism?\nAnswer: ', 'Q::: How much do you know about Buddhism?\nA::: ', 'q:::How much do you know about Buddhism?\na::: ', 'QUESTION:How much do you know about Buddhism?\nA: ', 'Q: How much do you know about Buddhism?\nAnswer: ', 'q:How much do you know about Buddhism?\na: ', 'Q: What is your level of experience with Buddhism?\nA: ', 'Q: How much information do you have about Buddhism?\nA: ', 'Q: What is your awareness of Buddhism?\nA: ', 'Q: What is your level of familiarity with Buddhism?\nA: ', 'Q: Are you familiar with the principles of Buddhism?\nA: ', 'Q: How well-versed are you in Buddhism?\nA: ', 'Q: What is your grasp of Buddhism?\nA: ']
# Response 0: ["\xa0I've been a Buddhist for over 20 years. I've been a Buddhist for over 20 years", '\xa0I have heard of it, and I have heard of it. I have heard of it,', "\xa0I've been to a lot of Buddhist temples and I've never seen anything like it. I", '\xa0I have been studying huddhism for a long time. \xa0I have been studying', '\xa0I am not sure if it is a Buddhist or not. I am not sure if it is', "\xa0I don't know about Buddhism, but I do know about the Buddha. I think that's", "\xa0I don't know. I don't know if it's a good idea to do it.", "\xa0I don't know. I'm not sure if I'm being honest or not. I'm", '\xa0I have no idea. I have no idea what I am talking about. I am not a', "\xa0I've been studying Buddhism for a long time. I've been studying Buddhism for a long time", "\xa0I've been studying Buddhism for a long time. I've been studying Buddhism for a long time", "\xa0I've been in the Buddhist community for about 20 years. I've been a Buddhist for about", '\xa0I have no idea. I have no idea what the Buddha taught. I have no idea what', "\xa0I've been studying Buddhism for a long time. I've been studying Buddhism for a long time", '\xa0I have been a Buddhist for over 20 years. I have been a Buddhist for over 20 years', '\xa0I have a lot of information about Buddhism. \xa0I have a lot of information about Buddhism', '\xa0I have been a Buddhist for over 20 years. I have been a Buddhist for over 20 years', "\xa0I've been to a lot of Buddhist schools, and I've never been a Buddhist. I", "\xa0I've been reading a lot of Buddhist texts. I've read a lot of Buddhist texts that", '\xa0I am very well versed in the teachings of the Buddha. I am also very well vers', '\xa0I have been studying Buddhism for a long time. I have been studying Buddhism for a long time']
#
# Prompt 1: ['Q:Explain the concept of cognitive biases.\nA: ', 'Q:Explain the cncept of cogintive biazses .\nA: ', 'Q:Explain the concept of cognitkve biases .\nA: ', 'Q:Epxlain te ocncept kf cgonitive biasse .\nA: ', 'Q:wxplain hte concuept of cogniive biasebs .\nA: ', 'Q:Exolain the concept oaf cognitive buiases .\nA: ', 'Q:Explain thr concept of cognitivd bliases .\nA: ', 'Q::Explain the concept of cognitive biases.\nA:: ', 'q:::Explain the concept of cognitive biases.\na::: ', 'Question: Explain the concept of cognitive biases. , Answer: ', 'Question: Explain the concept of cognitive biases.\nAnswer: ', 'Q: Explain the concept of cognitive biases. || A: ', 'Question:Explain the concept of cognitive biases.\nAnswer: ', 'q:: Explain the concept of cognitive biases.\na:: ', 'Q: Go over the concept of cognitive biases.\nA: ', 'Q: Elaborate on the notion of cognitive biases.\nA: ', 'Q: Give an account of the concept of cognitive biases.\nA: ', 'Q: Untangle the concept of cognitive biases.\nA: ', 'Q: Elucidate the notion of cognitive biases.\nA: ', 'Q: Spell out the concept of cognitive biases.\nA: ', 'Q: Characterize the concept of cognitive biases.\nA: ']
# Response 1: ['\xa0I think that cognitive biases are a very important part of the human condition. \xa0They are', "\xa0I think it's a bit of a stretch to say that the cncept of cogint", '\xa0I think that the idea of cognitkve biases is a bit of a stretch. ', '\xa0I am not sure if this is a good idea or not. I am not sure if this', '\xa0(1) \xa0(2) \xa0(3) \xa0(4) ', '\xa0The concept of buiases is a concept that is used to describe the cognitive abilities of people', '\xa0The concept of cognitivd bliases is a concept of the cognitivd', '\xa0I think that the term cognitive bias is a bit misleading. Cognitive biases are the tendency to think', '\xa0The concept of cognitive biases.\nb::: \xa0The concept of cognitive biases.\n', '\xa0I think that the term cognitive bias is a bit misleading. Cognitive biases are the tendency to think', "\xa0I think that the term cognitive bias is a bit misleading. \xa0It's a term that", '__________\n\nQ: What is the difference between cognitive biases and non-cognitive biases?', '\xa0I think that the concept of cognitive biases is a very important one. \xa0It is a', "\xa0I'm not sure if this is a good idea, but I think it's a good idea", "\xa0I think that's a good question. \xa0I think that's a good question. ", "\xa0I think that's a good question. I think that's a good question. I think that", "\xa0I think that's a good question. \xa0I think that's a good question. ", "\xa0I think that's a good question. \xa0I think that's a good question. ", "\xa0I think that's a good idea. \xa0I think that's a good idea. ", "\xa0I think that's a good idea. \xa0I think that's a good idea. ", '\xa0I think that the most important thing to understand about cognitive biases is that they are not just a']

# %%
# Extract paraphrased prompts (first 2 groups for now)
intent_aligned_prompts = [entry["prompts"] for entry in raw_data[:2]]

# Load model
# EleutherAI/gpt-neo-125M, mistralai/Mistral-7B-Instruct-v0.2
model = HFModel("EleutherAI/gpt-neo-125M")

# Run
score, trace = get_prompt_sensitivity(model, intent_aligned_prompts, config)
print(f"\nPSI score: {score:.4f}")

print("Total prompts in trace:", len(trace.prompts))
print("Total responses in trace:", len(trace.responses))

# Check first 3 prompts and responses
for i in range(min(3, len(trace.prompts))):
    print(f"\nPrompt {i}: {trace.prompts[i]}")
    print(f"→ Response {i}: {trace.responses[i]}")
# Out:
# Setting pad token to <|endoftext|>
#   0%|          | 0/2 [00:00<?, ?it/s]
# PSI score: 0.8236
# Total prompts in trace: 2
# Total responses in trace: 2
#
# Prompt 0: ['Q:How much do you know about Buddhism?\nA: ', 'Q:How much so yeou know about Buddhism ?\nA: ', 'Q:Hlow much do you know about Buddhism ?\nA: ', 'Q:How much do you know about huddhism ?\nA: ', 'Q:Hw muh dpo ypu knw abouht Buddhiism ?\nA: ', 'Q:yow much dmo oyu know about Buddhism ?\nA: ', 'Q:How much ddo you knod about Buddhism ?\nA: ', 'question: How much do you know about Buddhism?\nanswer: ', 'Question: How much do you know about Buddhism?\nAnswer: ', 'Q::: How much do you know about Buddhism?\nA::: ', 'q:::How much do you know about Buddhism?\na::: ', 'QUESTION:How much do you know about Buddhism?\nA: ', 'Q: How much do you know about Buddhism?\nAnswer: ', 'q:How much do you know about Buddhism?\na: ', 'Q: What is your level of experience with Buddhism?\nA: ', 'Q: How much information do you have about Buddhism?\nA: ', 'Q: What is your awareness of Buddhism?\nA: ', 'Q: What is your level of familiarity with Buddhism?\nA: ', 'Q: Are you familiar with the principles of Buddhism?\nA: ', 'Q: How well-versed are you in Buddhism?\nA: ', 'Q: What is your grasp of Buddhism?\nA: ']
# → Response 0: ['                    ', '                    ', '                    ', '                    ', '\n\nI have a question about the muh dpo ypu knw abouht Budd', '                    ', '                    ', "\n\nA:\n\nI don't know much about Buddhism, but I know that there are", '\n\n1. Buddhism is a religion of the Buddha.\n2. Buddhism is a religion of', '                    ', '                    ', " I don't know.\nB:  I don't know.\nC:  I don", '\n\nI have a question about Buddhism. I have a question about Buddhism. I have a question', '\n\nI have no idea.\n\nA:\n\nI have no idea.\n\n', ' I have been a Buddhist for a long time.  I have been a Buddhist for a long time', '                    ', ' I am not sure what you mean by "awareness of Buddhism".  I am not sure what you', " I'm not sure if you're familiar with Buddhism, but I think you're familiar with the concept", " \n\nI'm a Buddhist. I'm a Buddhist. I'm a Buddhist. I'm", ' I\'m not sure if you\'re familiar with the term "Buddha" or not. ', " I don't know.  I don't know what you're talking about.  I don't"]
#
# Prompt 1: ['Q:Explain the concept of cognitive biases.\nA: ', 'Q:Explain the cncept of cogintive biazses .\nA: ', 'Q:Explain the concept of cognitkve biases .\nA: ', 'Q:Epxlain te ocncept kf cgonitive biasse .\nA: ', 'Q:wxplain hte concuept of cogniive biasebs .\nA: ', 'Q:Exolain the concept oaf cognitive buiases .\nA: ', 'Q:Explain thr concept of cognitivd bliases .\nA: ', 'Q::Explain the concept of cognitive biases.\nA:: ', 'q:::Explain the concept of cognitive biases.\na::: ', 'Question: Explain the concept of cognitive biases. , Answer: ', 'Question: Explain the concept of cognitive biases.\nAnswer: ', 'Q: Explain the concept of cognitive biases. || A: ', 'Question:Explain the concept of cognitive biases.\nAnswer: ', 'q:: Explain the concept of cognitive biases.\na:: ', 'Q: Go over the concept of cognitive biases.\nA: ', 'Q: Elaborate on the notion of cognitive biases.\nA: ', 'Q: Give an account of the concept of cognitive biases.\nA: ', 'Q: Untangle the concept of cognitive biases.\nA: ', 'Q: Elucidate the notion of cognitive biases.\nA: ', 'Q: Spell out the concept of cognitive biases.\nA: ', 'Q: Characterize the concept of cognitive biases.\nA: ']
# → Response 1: ['                    ', '\n\nI have a question about the cncept of cogintive biazses.\n', '                    ', '\n\nEt voilà, il fatto che il fatto che il fatto che', '\n\nI have a problem with the following code:\n\n$(function () {\r\n', '                    ', '                    ', '                    ', '                    ', '_____.\n\n**1.** The concept of cognitive biases is a very important one. It', '\n\nCognitive biases are the tendency to think that something is important, but not necessarily the same', '                    ', ' \n\nA:\n\nThe concept of cognitive biases is a very important one. It is', '                    ', "\n\nI'm trying to understand the concept of cognitive biases. \nI'm trying to understand", '                    ', "\n\nI'm a bit confused by the following:\n\nThe concept of cognitive biases is a", "\n\nI'm trying to understand the concept of cognitive biases. \nI have a question about", '                    ', "\n\nI'm trying to understand the concept of cognitive biases. \nI have a problem with", "\n\nI'm trying to understand the concept of cognitive biases. \nI have a problem with"]

# %%
print("Mistralai")

# Extract paraphrased prompts (first 2 groups for now)
intent_aligned_prompts = [entry["prompts"] for entry in raw_data[:2]]

# Load model
# EleutherAI/gpt-neo-125M, mistralai/Mistral-7B-Instruct-v0.2
model = HFModel("mistralai/Mistral-7B-Instruct-v0.2")

# Run
score, trace = get_prompt_sensitivity(model, intent_aligned_prompts, config)
print(f"\nPSI score: {score:.4f}")

print("Total prompts in trace:", len(trace.prompts))
print("Total responses in trace:", len(trace.responses))

# Check first 3 prompts and responses
for i in range(min(3, len(trace.prompts))):
    print(f"\nPrompt {i}: {trace.prompts[i]}")
    print(f"→ Response {i}: {trace.responses[i]}")
# Out:
# Mistralai
# tokenizer_config.json:   0%|          | 0.00/2.10k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# Setting pad token to <unk>
#   0%|          | 0/2 [00:00<?, ?it/s]
# PSI score: 0.2828
# Total prompts in trace: 2
# Total responses in trace: 2
#
# Prompt 0: ['Q:How much do you know about Buddhism?\nA: ', 'Q:How much so yeou know about Buddhism ?\nA: ', 'Q:Hlow much do you know about Buddhism ?\nA: ', 'Q:How much do you know about huddhism ?\nA: ', 'Q:Hw muh dpo ypu knw abouht Buddhiism ?\nA: ', 'Q:yow much dmo oyu know about Buddhism ?\nA: ', 'Q:How much ddo you knod about Buddhism ?\nA: ', 'question: How much do you know about Buddhism?\nanswer: ', 'Question: How much do you know about Buddhism?\nAnswer: ', 'Q::: How much do you know about Buddhism?\nA::: ', 'q:::How much do you know about Buddhism?\na::: ', 'QUESTION:How much do you know about Buddhism?\nA: ', 'Q: How much do you know about Buddhism?\nAnswer: ', 'q:How much do you know about Buddhism?\na: ', 'Q: What is your level of experience with Buddhism?\nA: ', 'Q: How much information do you have about Buddhism?\nA: ', 'Q: What is your awareness of Buddhism?\nA: ', 'Q: What is your level of familiarity with Buddhism?\nA: ', 'Q: Are you familiar with the principles of Buddhism?\nA: ', 'Q: How well-versed are you in Buddhism?\nA: ', 'Q: What is your grasp of Buddhism?\nA: ']
# → Response 0: ['I can tell you that Buddhism is a religion and philosophy founded in ancient India. It is', 'I have a basic understanding of Buddhism as a major world religion that originated in ancient India', 'I can provide you with some basic information about Buddhism. Buddhism is a religion and', 'I can provide some basic information about Buddhism, but it is a complex and diverse religious tradition', 'I can provide you with some basic information about Buddhism. Buddhism is a religion and', 'It appears you are asking about how much I know about Buddhism. Buddhism is a', 'I can provide you with some basic information about Buddhism. Buddhism is a religion and', 'I have a basic understanding of Buddhism as a spiritual tradition that originated in ancient India.', 'I have a basic understanding of Buddhism as a major world religion that originated in ancient India', 'I can provide information on various aspects of Buddhism, including its history, teachings, practices', 'I can provide you with some basic information about Buddhism. Buddhism is a religion and', 'I can provide information on various aspects of Buddhism, including its history, beliefs, practices,', 'I have a basic understanding of Buddhism as a major world religion that originated in ancient India', 'I can tell you that Buddhism is a religion and philosophy founded in ancient India. It is', 'I have been studying and practicing Buddhism for over 25 years. I have a deep', 'I can provide you with a general overview of Buddhism, its history, beliefs, practices,', 'I have a basic understanding of Buddhism as a spiritual tradition that originated in ancient India.', 'I have a good understanding of the basic tenets of Buddhism, particularly as they relate to', 'Yes, I am familiar with the principles of Buddhism. Buddhism is a religion and', 'I have a good understanding of Buddhism, particularly in its Theravada and Mahayana', 'I have a basic understanding of Buddhism, but I am not an expert. Buddhism']
#
# Prompt 1: ['Q:Explain the concept of cognitive biases.\nA: ', 'Q:Explain the cncept of cogintive biazses .\nA: ', 'Q:Explain the concept of cognitkve biases .\nA: ', 'Q:Epxlain te ocncept kf cgonitive biasse .\nA: ', 'Q:wxplain hte concuept of cogniive biasebs .\nA: ', 'Q:Exolain the concept oaf cognitive buiases .\nA: ', 'Q:Explain thr concept of cognitivd bliases .\nA: ', 'Q::Explain the concept of cognitive biases.\nA:: ', 'q:::Explain the concept of cognitive biases.\na::: ', 'Question: Explain the concept of cognitive biases. , Answer: ', 'Question: Explain the concept of cognitive biases.\nAnswer: ', 'Q: Explain the concept of cognitive biases. || A: ', 'Question:Explain the concept of cognitive biases.\nAnswer: ', 'q:: Explain the concept of cognitive biases.\na:: ', 'Q: Go over the concept of cognitive biases.\nA: ', 'Q: Elaborate on the notion of cognitive biases.\nA: ', 'Q: Give an account of the concept of cognitive biases.\nA: ', 'Q: Untangle the concept of cognitive biases.\nA: ', 'Q: Elucidate the notion of cognitive biases.\nA: ', 'Q: Spell out the concept of cognitive biases.\nA: ', 'Q: Characterize the concept of cognitive biases.\nA: ']
# → Response 1: ['Cognitive biases refer to systematic errors or inconsistencies in our thinking and information processing.', 'Cognitive biases are systematic errors or deviations from rational judgment and reasoning that affect individuals', 'Cognitive biases refer to systematic errors or distortions in our thinking and perception of the', 'Cognitive biases are systematic errors or distortions in thinking and information processing. They are', 'Cognitive biases are systematic errors or distortions in thinking and information processing that can lead', 'Cognitive biases are systematic errors or deviations from rational judgment and reasoning that affect individuals', 'Cognitive biases refer to systematic errors or inconsistencies in our thinking and information processing.', 'Cognitive biases are systematic errors in thinking and reasoning that affect our judgments, decisions,', 'Cognitive biases refer to systematic errors or inconsistencies in our thinking and decision-making', 'Cognitive biases refer to systematic errors or inconsistencies in thinking, perception, memory,', 'Cognitive biases refer to systematic errors or deviations from rational judgment and reasoning that affect', 'Cognitive biases refer to systematic errors or inconsistencies in our thinking and information processing.', 'Cognitive biases refer to systematic errors or deviations from rational judgment and reasoning that affect', 'Cognitive biases are systematic errors in thinking and reasoning that affect our judgments, decisions,', 'Cognitive biases refer to systematic errors or deviations from rational judgment and reasoning that affect', 'Cognitive biases refer to systematic errors or deviations from rational judgment and logical reasoning that', 'Cognitive biases refer to systematic errors or deviations from rational judgment and reasoning that affect', 'Cognitive biases refer to systematic errors or inconsistencies in our thinking and decision-making', 'Cognitive biases refer to systematic errors or inconsistencies in thinking, perception, memory,', 'Cognitive biases refer to systematic errors or inconsistencies in thinking, perception, memory,', 'Cognitive biases refer to systematic errors or deviations from rational judgment and logical reasoning in']
